# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

kratice = ['ATL', 'BOS', 'SAS', 'NJN', 'CHA', 'CHI', 'CLE', 
           'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 
           'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOH', 'NYK', 
           'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'TOR',
           'UTA', 'WAS']
leta = list(range(1990, 2000))
url_start = "https://www.basketball-reference.com/teams/{}/{}_games.html"
base_dir = r"C:\Users\Timon\Desktop\PythonProjects\NBA_teams_through_years\NBA_TEAMS"

for leto in leta: 
    for ekipa in kratice:
        url = url_start.format(ekipa, leto)
        try:
            tables = pd.read_html(url)
        except Exception as e:
            print(f"Napaka pri {ekipa} {leto}: {e}")
            continue
        path = os.path.join(base_dir, ekipa, str(leto))
        os.makedirs(path, exist_ok=True)
        for i, df in enumerate(tables):
            csv_path = os.path.join(path, f"{ekipa}_{leto}_table_{i}.csv")
            df.to_csv(csv_path, index=False)
        time.sleep(10)
# Out:
# Napaka pri ATL 1990: HTTP Error 429: Too Many Requests
# Napaka pri BOS 1990: HTTP Error 429: Too Many Requests
# Napaka pri SAS 1990: HTTP Error 429: Too Many Requests
# Napaka pri NJN 1990: HTTP Error 429: Too Many Requests
# Napaka pri CHA 1990: HTTP Error 429: Too Many Requests
# Napaka pri CHI 1990: HTTP Error 429: Too Many Requests
# Napaka pri CLE 1990: HTTP Error 429: Too Many Requests
# Napaka pri DAL 1990: HTTP Error 429: Too Many Requests
# Napaka pri DEN 1990: HTTP Error 429: Too Many Requests
# Napaka pri DET 1990: HTTP Error 429: Too Many Requests
# Napaka pri GSW 1990: HTTP Error 429: Too Many Requests
# Napaka pri HOU 1990: HTTP Error 429: Too Many Requests
# Napaka pri IND 1990: HTTP Error 429: Too Many Requests
# Napaka pri LAC 1990: HTTP Error 429: Too Many Requests
# Napaka pri LAL 1990: HTTP Error 429: Too Many Requests
# Napaka pri MEM 1990: HTTP Error 429: Too Many Requests
# Napaka pri MIA 1990: HTTP Error 429: Too Many Requests
# ...
